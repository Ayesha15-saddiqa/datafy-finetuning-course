# %% [markdown]
# <a href="https://colab.research.google.com/github/amjadraza/datafy-finetuning-course/blob/main/notebooks/0_Preparing_setup_datafy_finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATAFY FINETUNING: Initial Setup

# %% [markdown]
# ## Pre-Requisite
#
# 1. GitHub Account: For the https://github.com/amjadraza/datafy-finetuning-course
# 2. Google Account: For Google Colab and Google Drive
#
# ## 💻 Generate API Key for LAMINI
#
# 1. Sign up on https://www.lamini.ai/
# 2. Go to Account and get the API key Under `Active API Tokens`
# 3. Under `.powerml/configure_llama.yaml`, add the key
# 4. `dotenv` can also be used to setup the key. Use the `env.example` to create `env` file
#
# for more on Authentcation read `https://lamini-ai.github.io/auth/`

# %% [markdown]
# Google Colab offer free GPU therefore, running on Google Colab is prefferd method
#
# 1. To get started, you need to mount your Google Drive in Colab. You can do this by running the following command:

# %%
# Mount the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Once your Drive is mounted, you can clone a repository by running the following command:

# %%
# !git clone https://github.com/amjadraza/datafy-finetuning-course.git /content/drive/MyDrive/datafy-finetuning-course
# Out:
# Cloning into '/content/drive/MyDrive/datafy-finetuning-course'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 5), reused 21 (delta 5), pack-reused 0
# Receiving objects: 100% (21/21), 422.45 KiB | 8.45 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/datafy-finetuning-course
# Out:
# /content/drive/MyDrive/datafy-finetuning-course

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/datafy-finetuning-course'

# %%
# !ls
# Out:
# docker-compose.yml  LICENSE    poetry.lock  pyproject.toml  requirements.txt
# Dockerfile	    notebooks  poetry.toml  README.md

# %% [markdown]
# upload the `.env` file to your google drive location with LAMINI_API_KEY
